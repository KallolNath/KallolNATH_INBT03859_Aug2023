# %% [markdown]
# # **Introduction**
#
# In the field of e-commerce, the datasets are typically considered as proprietary, meaning they are owned and controlled by individual organizations and are not often made publicly available due to privacy and business considerations. In spite of this, The UCI Machine Learning Repository, known for its extensive collection of datasets beneficial for machine learning and data mining research, has curated and made accessible a unique dataset. This dataset comprises actual transactional data spanning from the year 2010 to 2011. For those interested, the dataset is maintained and readily available on the UCI Machine Learning Repository's site under the title "Online Retail".
#
# ### **Content**
#
# The dataset is a transnational one, capturing every transaction made from December 1, 2010, through December 9, 2011, by a UK-based non-store online retail company. As an online retail entity, the company doesn't have a physical store presence, and its operations and sales are conducted purely online. The company's primary product offering includes unique gifts for all occasions. While the company serves a diverse range of customers, a significant number of its clientele includes wholesalers.

# %%
import numpy as np
import pandas as pd

# DATA VISUALIZATION LIB
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# ignoring wranings
import warnings
warnings.filterwarnings("ignore")

# %%
# reading the dataset

customer = pd.read_csv("/content/data.csv",encoding='unicode_escape')

# %%
customer.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
customer.tail(10)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541899    581587     22726       ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730       ALARM CLOCK BAKELIKE IVORY         4
# 541901    581587     22367  CHILDRENS APRON SPACEBOY DESIGN         8
# 541902    581587     22629              SPACEBOY LUNCH BOX         12
# 541903    581587     23256      CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541899  12/9/2011 12:50       3.75     12680.0  France
# 541900  12/9/2011 12:50       3.75     12680.0  France
# ...

# %%
customer.shape
# Out:
# (541909, 8)

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
customer.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# since there are null values, lets drop all the null values.

customer = customer.dropna()

# %%
customer.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  object
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 27.9+ MB

# %%
## Checking all the products whose quantity is in negative

customer.query("Quantity < 0")
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# Making the negative quantity positive

customer["Quantity"] = customer["Quantity"].abs()

# %%
customer.query("Quantity < 0")
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
## Checking all the products whose unitprice is in negative

customer.query("UnitPrice < 0")
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
customer['InvoiceDate']=pd.to_datetime(customer['InvoiceDate'],format='%m/%d/%Y %H:%M')

# %%
customer.insert(loc=3,column="year",value=customer.InvoiceDate.dt.year)

# %%
customer.insert(loc=3,column="month",value=customer.InvoiceDate.dt.month)

# %%
customer.insert(loc=3,column="day",value=customer.InvoiceDate.dt.day)

# %%
customer.insert(loc=3,column="hour",value=customer.InvoiceDate.dt.hour)

# %%
customer.head()
# Out:
#   InvoiceNo StockCode                          Description  hour  day  month  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER     8    1     12
# 1    536365     71053                  WHITE METAL LANTERN     8    1     12
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER     8    1     12
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     8    1     12
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.     8    1     12
#
#    year  Quantity         InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010         6 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010         6 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010         8 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010         6 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010         6 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Converting customerid from float to int
customer['CustomerID']=customer['CustomerID'].astype('int64')

# %%
customer.head()
# Out:
#   InvoiceNo StockCode                          Description  hour  day  month  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER     8    1     12
# 1    536365     71053                  WHITE METAL LANTERN     8    1     12
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER     8    1     12
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     8    1     12
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.     8    1     12
#
#    year  Quantity         InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010         6 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010         8 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom

# %%
## Creating a Total Amount Column by multiplying quantity and unit price

customer["Total_Amount"] = customer["Quantity"]*customer["UnitPrice"]
customer.head()
# Out:
#   InvoiceNo StockCode                          Description  hour  day  month  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER     8    1     12
# 1    536365     71053                  WHITE METAL LANTERN     8    1     12
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER     8    1     12
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     8    1     12
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.     8    1     12
#
#    year  Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010         6 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010         8 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
#
#    Total_Amount
# 0         15.30
# ...

# %%
# Let's check the Total count of customers in each country

count_of_customers = customer.groupby("Country")["CustomerID"].nunique().reset_index()
count_of_customers.columns = ["Country","Total_Customers"]
count_of_customers = count_of_customers.sort_values(by = "Total_Customers", ascending=False)
print(count_of_customers)
# Out:
#                  Country  Total_Customers
# 35        United Kingdom             3950
# 14               Germany               95
# 13                France               87
# 30                 Spain               31
# 3                Belgium               25
# 32           Switzerland               21
# 26              Portugal               19
# 18                 Italy               15
# 12               Finland               12
# 1                Austria               11
# 24                Norway               10
# 23           Netherlands                9
# 0              Australia                9
# 9                Denmark                9
# 6        Channel Islands                9
# 7                 Cyprus                8
# 31                Sweden                8
# 19                 Japan                8
# 25                Poland                6
# 33                   USA                4
# 5                 Canada                4
# ...

# %%
# Lets see a bar chart for Top 10 countries for Total Customer

Top_10_countries = count_of_customers.sort_values(by = "Total_Customers", ascending=False).head(10)

plt.figure(figsize=(12,8))
sns.barplot(data = Top_10_countries,x="Country",y="Total_Customers",palette='viridis')
plt.ylabel('Total Customers')
plt.xlabel('Country')
plt.title('Total Customer in Top10 countries')

plt.tight_layout()
plt.show()

# %%
## Lets see the Top 10 countries in terms of numbers of customers apart from UK

count_of_customers = count_of_customers[count_of_customers["Country"] != "United Kingdom"]

Top_10_countries = count_of_customers.sort_values(by = "Total_Customers", ascending=False).head(10)

plt.figure(figsize=(12,8))
sns.barplot(data = Top_10_countries,x="Country",y="Total_Customers",palette='viridis')
plt.ylabel('Total Customers')
plt.xlabel('Country')
plt.title('Total Customer in Top10 countries excluding United Kingdom')

plt.tight_layout()
plt.show()

# %%
# Let's check the Total Amount of orders coming from different country

TA_by_Countries = customer.groupby("Country")["Total_Amount"].sum().reset_index()

TA_by_Countries.columns = ["Country","Total_Amount"]
TA_by_Countries = TA_by_Countries.sort_values(by = "Total_Amount", ascending=False)
print(TA_by_Countries)
# Out:
#                  Country  Total_Amount
# 35        United Kingdom   7848909.714
# 23           Netherlands    286231.140
# 10                  EIRE    280806.580
# 14               Germany    236036.070
# 13                France    221335.260
# 0              Australia    139965.350
# 30                 Spain     68379.640
# 32           Switzerland     57148.500
# 3                Belgium     41481.720
# 31                Sweden     40160.750
# 19                 Japan     39492.120
# 26              Portugal     37819.970
# 24                Norway     37167.420
# 29             Singapore     33438.190
# 12               Finland     22765.420
# 6        Channel Islands     20814.590
# 9                Denmark     19142.540
# 18                 Italy     18075.970
# 7                 Cyprus     14234.470
# 1                Austria     10243.040
# 25                Poland      7456.160
# 17                Israel      7449.130
# 33                   USA      5429.860
# ...

# %%
## Visualizing Top 10 countries generating maximum revenue

Top_10_countries = TA_by_Countries.head(10)

plt.figure(figsize=(12,8))
ax = sns.barplot(data = Top_10_countries,x="Country",y="Total_Amount",palette='viridis')
plt.ylabel('Total Amount')
plt.xlabel('Country')
plt.title('Top10 countries with Max Total Amount')

ax.set_yticklabels(['{:.2f}M'.format(y / 1000000) for y in ax.get_yticks()])

plt.tight_layout()
plt.show()

# %%
## Visualizing Top 10 countries generating maximum revenue apart from UK

TA_by_Countries_exceptUK = TA_by_Countries[TA_by_Countries["Country"] != "United Kingdom"]

Top_10_countries = TA_by_Countries_exceptUK.head(10)

plt.figure(figsize=(12,8))
ax = sns.barplot(data = Top_10_countries,x="Country",y="Total_Amount",palette='viridis')
plt.ylabel('Total Amount')
plt.xlabel('Country')
plt.title('Top10 countries with Max Total Amount except UK')

ax.set_yticklabels(['{:.2f}L'.format(y / 100000) for y in ax.get_yticks()])

plt.tight_layout()
plt.show()

# %%
TA_by_Customers = customer.groupby("CustomerID")["Total_Amount"].sum().reset_index()

TA_by_Customers.columns = ["CustomerID","Total_Amount"]
TA_by_Customers = TA_by_Customers.sort_values(by = "Total_Amount", ascending=False)
print(TA_by_Customers )
# Out:
#       CustomerID  Total_Amount
# 3033       16446     336942.10
# 1703       14646     280923.02
# 4233       18102     262876.11
# 3758       17450     201619.41
# 1895       14911     155077.50
# ...          ...           ...
# 467        12943          3.75
# 3020       16428          2.95
# 1727       14679          2.55
# 3435       16995          1.25
# 692        13256          0.00
#
# [4372 rows x 2 columns]

# %%
# Lets check the Top 5 customers in terms of revenue

Top_5_customers = TA_by_Customers.head(5)

plt.figure(figsize=(12,8))
ax = sns.barplot(data = Top_5_customers,x="CustomerID",y="Total_Amount",palette='viridis')
plt.ylabel('Total Amount')
plt.xlabel('CustomerID')
plt.title('Top5 customers with Max Total Amount')

ax.set_yticklabels(['{:.2f}L'.format(y / 100000) for y in ax.get_yticks()])

plt.tight_layout()
plt.show()

# %%
## lets find the top 15 products in terms of quantity sold

Top_Products = customer["Description"].value_counts().head(15)

plt.figure(figsize=(12, 6))
sns.barplot(x=Top_Products.values, y=Top_Products.index, palette='viridis')
plt.title("Top 15 Products Sold")
plt.xlabel("Quantity")
plt.ylabel("Product Description")
plt.show()

# %%
# Lets check the number of free items

free_items = customer[customer.Total_Amount == 0]
free_items.head()
# Out:
#       InvoiceNo StockCode                   Description  hour  day  month  \
# 9302     537197     22841  ROUND CAKE TIN VINTAGE GREEN    14    5     12
# 33576    539263     22580  ADVENT CALENDAR GINGHAM SACK    14   16     12
# 40089    539722     22423      REGENCY CAKESTAND 3 TIER    13   21     12
# 47068    540372     22090       PAPER BUNTING RETROSPOT    16    6      1
# 47070    540372     22553        PLASTERS IN TIN SKULLS    16    6      1
#
#        year  Quantity         InvoiceDate  UnitPrice  CustomerID  \
# 9302   2010         1 2010-12-05 14:02:00        0.0       12647
# 33576  2010         4 2010-12-16 14:36:00        0.0       16560
# 40089  2010        10 2010-12-21 13:45:00        0.0       14911
# 47068  2011        24 2011-01-06 16:41:00        0.0       13081
# 47070  2011        24 2011-01-06 16:41:00        0.0       13081
#
#               Country  Total_Amount
# 9302          Germany           0.0
# 33576  United Kingdom           0.0
# ...

# %%
## Visualizing in which month we have offered maximum free items

mfu = free_items.month.value_counts().sort_index()
plt.figure(figsize=(10,6))
mfu.plot(kind="bar",colormap = "cividis")
plt.title('Monthly Free Units')
plt.xlabel("Month")
plt.show()

# %%
# Lets find the Number of order per year

orders_per_year = customer.groupby(by = ["InvoiceNo","year"])["year"].unique().value_counts().sort_index()
plt.figure(figsize=(10,6))
orders_per_year.plot(kind="bar",colormap = "cividis")
plt.title('Number of Orders per year')

plt.show()

# %%
# Lets find the Number of order per month

orders_per_month = customer.groupby(by = ["InvoiceNo","month"])["month"].unique().value_counts().sort_index()
plt.figure(figsize=(12,6))
orders_per_month.plot(kind="line", colormap ='cividis')
plt.title('Number of Orders per month')

plt.show()

# %%
# Lets find the Number of order per day

orders_per_day = customer.groupby(by = ["InvoiceNo","day"])["day"].unique().value_counts().sort_index()
plt.figure(figsize=(12,6))
orders_per_day.plot(kind="line", colormap ='cividis')
plt.title('Number of Orders per day in a month')

plt.show()

# %%
# Lets calculate the correlation among the number columns
correlation = customer.select_dtypes(include=['number'])

# Calculate the correlation
correlation = correlation.corr()
correlation
# Out:
#                   hour       day     month      year  Quantity  UnitPrice  \
# hour          1.000000  0.008186  0.055541 -0.019697 -0.012517   0.001672
# day           0.008186  1.000000 -0.118598  0.168057 -0.000994  -0.001893
# month         0.055541 -0.118598  1.000000 -0.341638 -0.003007  -0.003179
# year         -0.019697  0.168057 -0.341638  1.000000  0.001271   0.000979
# Quantity     -0.012517 -0.000994 -0.003007  0.001271  1.000000  -0.001335
# UnitPrice     0.001672 -0.001893 -0.003179  0.000979 -0.001335   1.000000
# CustomerID    0.064163 -0.001770  0.030612 -0.035955 -0.005102  -0.004560
# Total_Amount -0.011206 -0.001971 -0.001736  0.000872  0.916042   0.165648
#
#               CustomerID  Total_Amount
# hour            0.064163     -0.011206
# day            -0.001770     -0.001971
# month           0.030612     -0.001736
# year           -0.035955      0.000872
# Quantity       -0.005102      0.916042
# UnitPrice      -0.004560      0.165648
# ...

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(correlation, annot=True, cmap="viridis")
plt.show()

# %% [markdown]
# ## **Feature Engineering**

# %%
customer.head()
# Out:
#   InvoiceNo StockCode                          Description  hour  day  month  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER     8    1     12
# 1    536365     71053                  WHITE METAL LANTERN     8    1     12
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER     8    1     12
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     8    1     12
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.     8    1     12
#
#    year  Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010         6 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010         8 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
#
#    Total_Amount
# 0         15.30
# ...

# %%
customer.describe()
# Out:
#                 hour            day          month           year  \
# count  406829.000000  406829.000000  406829.000000  406829.000000
# mean       12.737472      15.036128       7.605947    2010.934002
# std         2.284952       8.653730       3.418942       0.248279
# min         6.000000       1.000000       1.000000    2010.000000
# 25%        11.000000       7.000000       5.000000    2011.000000
# 50%        13.000000      15.000000       8.000000    2011.000000
# 75%        14.000000      22.000000      11.000000    2011.000000
# max        20.000000      31.000000      12.000000    2011.000000
#
#             Quantity      UnitPrice     CustomerID   Total_Amount
# count  406829.000000  406829.000000  406829.000000  406829.000000
# mean       13.412279       3.460471   15287.690570      23.407255
# std       248.624170      69.315162    1713.600303     427.437730
# min         1.000000       0.000000   12346.000000       0.000000
# ...

# %%
plt.hist(customer["Total_Amount"])
# Out:
# (array([4.06823e+05, 0.00000e+00, 2.00000e+00, 0.00000e+00, 2.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 2.00000e+00]),
#  array([     0.  ,  16846.96,  33693.92,  50540.88,  67387.84,  84234.8 ,
#         101081.76, 117928.72, 134775.68, 151622.64, 168469.6 ]),
#  <BarContainer object of 10 artists>)

# %%
# To make the Total_Amount column more symmetric
##  I can add another column by taking the natural log of eachvalue in Total_Amount column


customer['Log_Total_Spending']=np.log1p(customer['Total_Amount'])

# %%
plt.hist(customer["Log_Total_Spending"])
# Out:
# (array([5.00340e+04, 1.34315e+05, 1.83463e+05, 2.96890e+04, 7.97700e+03,
#         1.12100e+03, 2.12000e+02, 1.20000e+01, 2.00000e+00, 4.00000e+00]),
#  array([ 0.        ,  1.20345165,  2.40690331,  3.61035496,  4.81380661,
#          6.01725827,  7.22070992,  8.42416157,  9.62761323, 10.83106488,
#         12.03451653]),
#  <BarContainer object of 10 artists>)

# %%
#Grouping the data by annual spending of each customer
annual_spending = customer.groupby('CustomerID')['Total_Amount'].sum()

customer = customer.merge(annual_spending, on='CustomerID', suffixes=('', '_AnnualSpending'))
customer.head()
# Out:
#   InvoiceNo StockCode                          Description  hour  day  month  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER     8    1     12
# 1    536365     71053                  WHITE METAL LANTERN     8    1     12
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER     8    1     12
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     8    1     12
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.     8    1     12
#
#    year  Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010         6 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010         8 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
#
# ...

# %%
customer.shape
# Out:
# (406829, 15)

# %%
## Dropping duplicates

customer.drop_duplicates(inplace=True)
customer.shape
# Out:
# (401604, 15)

# %%
## encoding categorical value

from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
customer["country_encoded"] = labelencoder.fit_transform(customer["Country"])

customer.head()
# Out:
#   InvoiceNo StockCode                          Description  hour  day  month  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER     8    1     12
# 1    536365     71053                  WHITE METAL LANTERN     8    1     12
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER     8    1     12
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     8    1     12
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.     8    1     12
#
#    year  Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010         6 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010         8 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
#
# ...

# %% [markdown]
# ## **Model Building**

# %%
# Train Test Split
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics

X = customer[["Quantity","UnitPrice","country_encoded","year"]]
Y = customer["Total_Amount"]

x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (321283, 4)
# (80321, 4)
# (321283,)
# (80321,)

# %% [markdown]
# ### **Liner Regression**

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
lr_pred_y_train=lr.predict(x_train)
lr_pred_y_test=lr.predict(x_test)

# %% [markdown]
# ### **DecisionTree Regressor**

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor(random_state=10)
dt.fit(x_train, y_train)
dt_pred_y_train = dt.predict(x_train)
dt_pred_y_test = dt.predict(x_test)

# %% [markdown]
# ### **Random Forest Regressor**

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state=42)
rf.fit(x_train,y_train)
rf_pred_y_train = rf.predict(x_train)
rf_pred_y_test = rf.predict(x_test)

# %% [markdown]
# ## **Model Evaluation**

# %% [markdown]
# ### **Linear Regression**

# %%
# Performance evaluation of training data for Linear Regression

print("Training Model Performance of Linear Regression \n")

print("Mean absolute error      :",metrics.mean_absolute_error(y_train,lr_pred_y_train))
print("Mean squared error       :",metrics.mean_squared_error(y_train,lr_pred_y_train))
print("Root mean squared error  :",np.sqrt(metrics.mean_squared_error(y_train,lr_pred_y_train)))
print("R2 Score                 :",metrics.r2_score(y_train,lr_pred_y_train))
# Out:
# Training Model Performance of Linear Regression
#
# Mean absolute error      : 13.020834679223878
# Mean squared error       : 29210.540104518586
# Root mean squared error  : 170.91091277188414
# R2 Score                 : 0.8729793121943755

# %%
# Performance evaluation of testing data for Linear Regression

print("Testing Model Performance of Linear Regression \n")

print("Mean absolute error      :",metrics.mean_absolute_error(y_test,lr_pred_y_test))
print("Mean squared error       :",metrics.mean_squared_error(y_test,lr_pred_y_test))
print("Root mean squared error  :",np.sqrt(metrics.mean_squared_error(y_test,lr_pred_y_test)))
print("R2 Score                 :",metrics.r2_score(y_test,lr_pred_y_test))
# Out:
# Testing Model Performance of Linear Regression
#
# Mean absolute error      : 12.367309935636566
# Mean squared error       : 6217.4626206195735
# Root mean squared error  : 78.85088852143376
# R2 Score                 : -0.1362250548004833

# %% [markdown]
# ### **DecisionTree Regressor**

# %%
# Performance evaluation of training data for DecisionTree Regression

print("Training Model Performance of DecisionTree Regression \n")

print("Mean absolute error      :",metrics.mean_absolute_error(y_train,dt_pred_y_train))
print("Mean squared error       :",metrics.mean_squared_error(y_train,dt_pred_y_train))
print("Root mean squared error  :",np.sqrt(metrics.mean_squared_error(y_train,dt_pred_y_train)))
print("R2 Score                 :",metrics.r2_score(y_train,dt_pred_y_train))
# Out:
# Training Model Performance of DecisionTree Regression
#
# Mean absolute error      : 2.352903222020798e-13
# Mean squared error       : 2.7826739523311954e-25
# Root mean squared error  : 5.275105640962269e-13
# R2 Score                 : 1.0

# %%
# Performance evaluation of testing data for DecisionTree Regression

print("Testing Model Performance of DecisionTree Regression \n")

print("Mean absolute error      :",metrics.mean_absolute_error(y_test,dt_pred_y_test))
print("Mean squared error       :",metrics.mean_squared_error(y_test,dt_pred_y_test))
print("Root mean squared error  :",np.sqrt(metrics.mean_squared_error(y_test,dt_pred_y_test)))
print("R2 Score                 :",metrics.r2_score(y_test,dt_pred_y_test))
# Out:
# Testing Model Performance of DecisionTree Regression
#
# Mean absolute error      : 0.19287670721254693
# Mean squared error       : 135.901428725987
# Root mean squared error  : 11.657676815128603
# R2 Score                 : 0.9751643688553031

# %% [markdown]
# ### **RandomForest Regressor**

# %%
# Performance evaluation of training data for RandomForest Regression

print("Training Model Performance of RandomForest Regression \n")

print("Mean absolute error      :",metrics.mean_absolute_error(y_train,rf_pred_y_train))
print("Mean squared error       :",metrics.mean_squared_error(y_train,rf_pred_y_train))
print("Root mean squared error  :",np.sqrt(metrics.mean_squared_error(y_train,rf_pred_y_train)))
print("R2 Score                 :",metrics.r2_score(y_train,rf_pred_y_train))
# Out:
# Training Model Performance of RandomForest Regression
#
# Mean absolute error      : 0.3049497563208593
# Mean squared error       : 2440.7147973904416
# Root mean squared error  : 49.403590936190476
# R2 Score                 : 0.9893866641564104

# %%
# Performance evaluation of testing data for RandomForest Regression

print("Testing Model Performance of RandomForest Regression \n")

print("Mean absolute error      :",metrics.mean_absolute_error(y_test,rf_pred_y_test))
print("Mean squared error       :",metrics.mean_squared_error(y_test,rf_pred_y_test))
print("Root mean squared error  :",np.sqrt(metrics.mean_squared_error(y_test,rf_pred_y_test)))
print("R2 Score                 :",metrics.r2_score(y_test,rf_pred_y_test))
# Out:
# Testing Model Performance of RandomForest Regression
#
# Mean absolute error      : 0.2721959356831793
# Mean squared error       : 302.1864404703885
# Root mean squared error  : 17.383510591085695
# R2 Score                 : 0.9447762172715378

# %% [markdown]
# ### **Accuracy of Training Data**

# %%
print("Accuracy of Training data of Linear Regression                : {:.2f}  ".format(lr.score(x_train,y_train)))
print("                                                                  ")
print("                                                                  ")
print("Accuracy of Training data of DecisionTree Regression          : {:.2f}  ".format(dt.score(x_train,y_train)))
print("                                                                  ")
print("                                                                  ")
print("Accuracy of Training data of RandomForest Regression          : {:.2f}  ".format(rf.score(x_train,y_train)))
# Out:
# Accuracy of Training data of Linear Regression                : 0.87
#
#
# Accuracy of Training data of DecisionTree Regression          : 1.00
#
#
# Accuracy of Training data of RandomForest Regression          : 0.99

# %%
print("Accuracy of Testing data of Linear Regression                : {:.2f}  ".format(lr.score(x_test,y_test)))
print("                                                                  ")
print("                                                                  ")
print("Accuracy of Testing data of DecisionTree Regression          : {:.2f}  ".format(dt.score(x_test,y_test)))
print("                                                                  ")
print("                                                                  ")
print("Accuracy of Testing data of RandomForest Regression          : {:.2f}  ".format(rf.score(x_test,y_test)))
# Out:
# Accuracy of Testing data of Linear Regression                : -0.14
#
#
# Accuracy of Testing data of DecisionTree Regression          : 0.98
#
#
# Accuracy of Testing data of RandomForest Regression          : 0.94

# %% [markdown]
# Since RandomForest Regressor model performs pretty well with training and testing data. we can move forward with this model

# %% [markdown]
# ## **Customer Segmentation**

# %%
customer.head()
# Out:
#   InvoiceNo StockCode                          Description  hour  day  month  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER     8    1     12
# 1    536365     71053                  WHITE METAL LANTERN     8    1     12
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER     8    1     12
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     8    1     12
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.     8    1     12
#
#    year  Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010         6 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010         8 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
#
# ...

# %%
## Changing column name

customer.rename(columns = {"Total_Amount_AnnualSpending":"Annual_Spending"}, inplace=True)
customer.head()
# Out:
#   InvoiceNo StockCode                          Description  hour  day  month  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER     8    1     12
# 1    536365     71053                  WHITE METAL LANTERN     8    1     12
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER     8    1     12
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     8    1     12
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.     8    1     12
#
#    year  Quantity         InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010         6 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2  2010         8 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4  2010         6 2010-12-01 08:26:00       3.39       17850  United Kingdom
#
# ...

# %%
# Getting the recent date from invoicedate column
recent_date = customer["InvoiceDate"].max()

## Calculating recency based on the recent date
rfm_data = customer.groupby("CustomerID").agg({
    "InvoiceDate":lambda x:(recent_date - x.max()).days,
    "InvoiceNo":"nunique",
    "Total_Amount":"sum"
})

rfm_data.rename(columns = {
    "InvoiceDate":"Recency",
    "InvoiceNo":"Frequency",
    "Total_Amount":"Monetory_Value"
}, inplace=True)

rfm_data.head()
# Out:
#             Recency  Frequency  Monetory_Value
# CustomerID
# 12346           325          2       154367.20
# 12347             1          7         4310.00
# 12348            74          4         1797.24
# 12349            18          1         1757.55
# 12350           309          1          334.40

# %%
## Plotting a 3D representation of rfm_data

fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111,projection='3d')

ax.scatter(rfm_data['Recency'],rfm_data['Frequency'],rfm_data['Monetory_Value'],cmap='viridis',s=50)
ax.set_xlabel('Recency')
ax.set_ylabel('Frequency')
ax.set_zlabel('Monetory Value')
ax.set_title('3D Representation of RFM Metrics')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
rfm_scaled=scaler.fit_transform(rfm_data)

# %%
## Importing kmeans
from sklearn.cluster import KMeans, AgglomerativeClustering

# checking the best value of k value from 1 to 10
inertia_values=[]
k_range=range(1,11)
for k in k_range:
    kmeans=KMeans(n_clusters=k,random_state=42)
    kmeans.fit(rfm_scaled)
    inertia_values.append(kmeans.inertia_)

# %%
plt.figure(figsize=(12,8))
plt.plot(k_range,inertia_values,marker='o')
plt.xlabel('Number of Clusters(k)')
plt.ylabel('Within-Clusters Sum of Squares(Inertia)')
plt.title('Optimal value of k ')
plt.xticks(k_range)
plt.grid(True)
plt.show()

# %%
# Applying K-Means clustring to create clusters based on RFM metrics
kmeans=KMeans(n_clusters=4,random_state=42)
rfm_data['KMeans_Cluster']=kmeans.fit_predict(rfm_scaled)

# %%
print("K-Means Clustering\n")
print(rfm_data['KMeans_Cluster'].value_counts())
# Out:
# K-Means Clustering
#
# 0    3156
# 3    1084
# 2     123
# 1       9
# Name: KMeans_Cluster, dtype: int64

# %%
# Plotting the clustered group of data in a scatter plot

plt.figure(figsize=(10,8))
sns.scatterplot(data=rfm_data,x='Frequency',y='Monetory_Value',hue='KMeans_Cluster',palette='Set1',s=50)
plt.scatter(kmeans.cluster_centers_[:,1],kmeans.cluster_centers_[:,2],c='red',marker='X',s=200,label='Cluster Centers')
plt.xlabel('Frequency')
plt.ylabel('Monetory Value')
plt.title('RFM Customer Segmentation using K-Means Clustering (k=4)')
plt.legend()
plt.grid(True)
plt.show()

# %%
fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111,projection='3d')

ax.scatter(rfm_data['Recency'],rfm_data['Frequency'],rfm_data['Monetory_Value'],c=rfm_data['KMeans_Cluster'],cmap='viridis',s=50)
ax.set_xlabel('Recency')
ax.set_ylabel('Frequency')
ax.set_zlabel('Monetory Value')
ax.set_title('3D Representation of RFM Metrics with Clusters')
plt.show()

# %%
# Apply Agglomerative Hierarchical Clustering
agg_clustering=AgglomerativeClustering(n_clusters=4)
rfm_data['Agg_Cluster']=agg_clustering.fit_predict(rfm_scaled)

# %%
print("\nAgglomerative Hierarchical Clustering")
print(rfm_data['Agg_Cluster'].value_counts())
# Out:
# Agglomerative Hierarchical Clustering
# 0    3035
# 2    1305
# 1      29
# 3       3
# Name: Agg_Cluster, dtype: int64

# %%
fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111,projection='3d')
ax.scatter(rfm_data['Recency'],rfm_data['Frequency'],rfm_data['Monetory_Value'],c=rfm_data['Agg_Cluster'],cmap='viridis',s=50)
ax.set_xlabel('Recency')
ax.set_ylabel('Frequency')
ax.set_zlabel('Monetory Value')
ax.set_title('3D Represenation of RFM Metrics with Cluster - Agglomerative Clustering')
plt.show()

# %% [markdown]
# # **Interpretation of Results**
#
# ### **Low-Recency, Low-Frequency, Low-Monetary**
#
# *   These customers have low Recency, which means they have recently made purchases.
# *   They also have low Frequency and low Monetary Value, which means they have spend little money and only made few purchases.
#
# *   All in all we can say that. They come in the category of customers who have recently made small purchases. To attract these customers for further purchases and ultametely to be a loyal customer, we can provide them with offers or coupons.
#
#
# ### **High-Recency, Low-Frequency, Low-Monetary**
#
# *   These customers have High Recency which means they have been inactive for quite a some time and not made any recent purchases.
# *   Also the purchases that they made before were of low monetary value that means they consumed less than other customers.
#
# *   Since the frequency is low we can say that they were not the loyal or frequent customers. So, we can say that they come in a category of customers who have made small purchases before and now they are inactive.
#
#
# ### **Low-Recency, High-Frequency, High-Monetary**
#
# *   These Customers have High Frequency, High Monetary and Low Recency, it means that they are the customers who have made frequent purcahses with high value products.
#
# *   We can say that these people come in the category of loyal customers who purchase high value products and can be termed as major source of income for the company.
#
#
# ### **High-Recency, High-Frequency, High-Monetary**
#
# *   These customers have High Frequency and High Monetary, it means they are the customers who purchase frequently in a high monetory value.
# *   They have High Recency which indicates that they have not purchased anything recently.
#
# *   We can say that, They are the customers who come into loyal customers category, who have made high monetary purchases frequently but haven't purchased anything in recent past. So, to attract them more, they should be offered frequent customized offers to keep them around.
